# %%
import networkx as nx
import numpy as np
import pickle
from kmapper import jupyter
import datetime
import pandas as pd


from src.mapper import MapperTopology
from sklearn.cluster import DBSCAN


from utils import get_diagrams,convert_to_gtda
from persim import plot_diagrams

import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/81/4smyjgm56s7gm79ptgb726s904l6lt/T/ipykernel_5828/1203091132.py in <module>
#       7
#       8
# ----> 9 from mapper import MapperTopology
#      10 from sklearn.cluster import DBSCAN
#      11
#
# ModuleNotFoundError: No module named 'mapper'

# %% [markdown]
# # Load Data

# %%
with open('../data/coal_mapper_one_hot_scaled_TSNE.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
#TSNE Projected for Local Ex.
ax = df.plot(x="x",y="y",kind="scatter")
plt.title("TSNE-Projected Coal Plant Data")
plt.show()

# %% [markdown]
# # Mapper Topology Object

# %%
arr = df.values

# Instantiate Object with Dataset
X = MapperTopology(X=arr)

cover = (6,0.4) #(hyper_cubes,percent_overlap)

# %%
# Compute Mapper Algorithm

X.set_graph(cover)
# Out:
# Computing Mapper Algorithm...
# Setting Lens
# Setting Cover
# Generating networkx Graph...
# Using Ollivier Ricci filtration to compute edge curvature values and persistence diagrams.

# %% [markdown]
# ## Contains:
# * mapper object
# * graph
# * edge curvature values
# * corresponding persistence diagram

# %%
#Mapper
mapper = X.mapper


html_path = mapper.plot()
# Out:
# ../outputs/htmls/coal_mapper_1678281747.html
# Go to ../outputs/htmls/coal_mapper_1678281747.html for a visualization of your CoalMapper!

# %%
jupyter.display(path_html=html_path)
# Out:
# <style>
#         .container { width:100% !important; }
#         .output_scroll {height: 800px !important;}
#         </style>
# <iframe src=../outputs/htmls/coal_mapper_1678281747.html width=100%% height=800 frameBorder="0"></iframe>

# %%
#NetworkX Graph
nx.draw(X.graph,node_size=10)

# %%
#Curvature
X.curvature
# Out:
# array([ 0.00000000e+00,  5.00000000e-01,  5.00000000e-01,  5.00000000e-01,
#         2.22044605e-16,  5.00000000e-01, -5.00000000e-01,  5.00000000e-01,
#         2.22044605e-16,  1.66666667e-01,  1.11022302e-16,  1.66666667e-01,
#        -2.00000000e-01,  6.66666667e-01,  0.00000000e+00,  0.00000000e+00,
#         1.66666667e-01,  2.22044605e-16,  1.66666667e-01,  1.11022302e-16,
#         1.66666667e-01, -2.00000000e-01,  6.66666667e-01,  6.66666667e-01,
#         7.50000000e-01,  6.00000000e-01,  6.66666667e-01,  6.00000000e-01,
#        -1.26666667e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  2.50000000e-01,  2.50000000e-01,  2.50000000e-01,
#         2.50000000e-01,  7.50000000e-01,  2.50000000e-01,  2.50000000e-01,
#         7.50000000e-01,  7.50000000e-01,  5.00000000e-01,  5.00000000e-01,
#         7.50000000e-01,  5.00000000e-01,  5.00000000e-01,  5.00000000e-01,
#         5.00000000e-01,  0.00000000e+00,  0.00000000e+00,  3.33333333e-01,
#         5.00000000e-01, -8.33333333e-01,  3.33333333e-01,  6.66666667e-01,
#         8.33333333e-02,  3.33333333e-01,  8.33333333e-02,  3.33333333e-01,
#         2.50000000e-01,  4.00000000e-01,  2.50000000e-01,  4.00000000e-01,
#         5.00000000e-01,  6.66666667e-01, -1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.14285714e-01,  3.33333333e-01,  3.33333333e-01,
#         3.33333333e-01,  3.33333333e-01,  5.00000000e-01,  2.22044605e-16,
#         2.85714286e-01,  2.38095238e-01,  2.85714286e-01,  2.38095238e-01,
#         3.57142857e-01,  5.00000000e-01,  6.66666667e-01,  5.00000000e-01,
#         4.00000000e-01,  6.66666667e-01,  4.00000000e-01,  4.00000000e-01,
#         4.00000000e-01,  4.00000000e-01,  8.00000000e-01,  4.00000000e-01,
#         4.00000000e-01,  4.00000000e-01,  6.66666667e-01,  2.50000000e-01,
#         2.50000000e-01,  5.00000000e-01,  0.00000000e+00,  3.33333333e-01,
#         3.33333333e-01,  5.00000000e-01,  5.00000000e-01,  5.00000000e-01,
#         6.66666667e-01,  6.66666667e-01,  6.66666667e-01,  0.00000000e+00,
#         0.00000000e+00,  4.00000000e-01,  5.00000000e-01,  4.00000000e-01,
#         4.00000000e-01,  6.00000000e-01, -1.20000000e+00,  6.00000000e-01,
#         5.00000000e-01,  6.00000000e-01,  4.00000000e-01, -1.10000000e+00,
#         0.00000000e+00,  0.00000000e+00,  6.00000000e-01,  4.00000000e-01,
#         6.66666667e-01,  6.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         5.00000000e-01,  5.00000000e-01,  3.33333333e-01,  5.00000000e-01,
#         5.00000000e-01,  3.33333333e-01, -1.00000000e+00,  4.00000000e-01,
#         3.33333333e-01, -2.00000000e-01,  4.00000000e-01,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         6.66666667e-01,  6.66666667e-01,  6.66666667e-01,  6.66666667e-01,
#         6.66666667e-01,  6.66666667e-01,  6.66666667e-01, -1.11111111e-01,
#         6.66666667e-01, -1.11111111e-01,  6.66666667e-01, -1.11111111e-01,
#        -1.11111111e-01, -1.11111111e-01, -1.11111111e-01, -1.11111111e-01,
#        -1.11111111e-01, -1.11111111e-01,  6.66666667e-01,  6.66666667e-01,
#         6.66666667e-01,  6.66666667e-01,  6.66666667e-01,  6.66666667e-01,
#         6.66666667e-01,  6.66666667e-01,  6.66666667e-01,  6.66666667e-01,
#         6.66666667e-01,  6.66666667e-01,  1.66666667e-01,  6.66666667e-01,
#         4.00000000e-01, -4.16666667e-02, -1.25000000e-01,  1.66666667e-01,
#        -4.16666667e-02,  1.66666667e-01,  3.25000000e-01, -4.16666667e-02,
#         4.00000000e-01,  2.50000000e-01,  4.00000000e-01,  1.66666667e-01,
#         4.00000000e-01,  4.00000000e-01,  8.00000000e-01, -3.33333333e-01,
#         1.66666667e-01,  1.11022302e-16,  1.66666667e-01,  1.66666667e-01,
#         4.00000000e-01,  4.00000000e-01,  6.66666667e-01,  6.66666667e-01,
#         6.66666667e-01,  5.00000000e-01,  3.33333333e-01,  0.00000000e+00])

# %%
# Persistence Diagram
X.plot_diagrams()

# %% [markdown]
# # Understanding Hyperparameter space
# * see hyperparameter_analysis script!

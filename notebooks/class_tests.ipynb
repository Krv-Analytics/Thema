# %%
import numpy as np
import pandas as pd
import kmapper as km
import networkx as nx
import matplotlib 
import sklearn
from sklearn import ensemble

import sys
sys.path.append("../")
from coal_mapper.mapper import CoalMapper

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Testing with Breast Cancer Data Set

# %%
df = pd.read_csv("/Users/jeremy.wayland/Downloads/data.csv")
feature_names = [c for c in df.columns if c not in ["id", "diagnosis"]]
df["diagnosis"] = df["diagnosis"].apply(lambda x: 1 if x == "M" else 0)
X = np.array(df[feature_names].fillna(0))  # quick and dirty imputation
y = np.array(df["diagnosis"])

# %%
# Create Object
test = CoalMapper(X=X)

# %%
#Check Data
test.data
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 4.601e-01, 1.189e-01,
#         0.000e+00],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 2.750e-01, 8.902e-02,
#         0.000e+00],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 3.613e-01, 8.758e-02,
#         0.000e+00],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 2.218e-01, 7.820e-02,
#         0.000e+00],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 4.087e-01, 1.240e-01,
#         0.000e+00],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 2.871e-01, 7.039e-02,
#         0.000e+00]])

# %%
# Construct Lens as in KM example
model = ensemble.IsolationForest(random_state=1729)
model.fit(X)
lens1 = model.decision_function(X).reshape((X.shape[0], 1))

mapper = km.KeplerMapper(verbose=3)
lens2 = mapper.fit_transform(X, projection="l2norm")
# Out:
# KeplerMapper(verbose=3)
# ..Composing projection pipeline of length 1:
# 	Projections: l2norm
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (569, 31)
#
# ..Projecting data using: l2norm
#
# ..Scaling with: MinMaxScaler()

# %%
# Assign Lens and Clusterer to Object
test.lens = np.c_[lens1, lens2]
test.clusterer = sklearn.cluster.KMeans(n_clusters=2, random_state=1618033)

# %%
# Compute Mapper with Object
test.compute_mapper(n_cubes=2, perc_overlap=0.4)

# %%
# Check Output, saved as mapper attribute
test.mapper
# Out:
# {'nodes': defaultdict(list,
#              {'cube0_cluster0': [0,
#                12,
#                18,
#                23,
#                24,
#                25,
#                42,
#                72,
#                77,
#                78,
#                82,
#                83,
#                108,
#                119,
#                122,
#                161,
#                164,
#                181,
#                197,
#                202,
#                210,
#                219,
#                233,
#                237,
#                250,
#                252,
#                256,
#                260,
#                272,
#                302,
#                323,
#                343,
#                366,
#                369,
#                373,
#                389,
#                393,
#                400,
#                417,
#                449,
#                451,
#                468,
#                491,
#                503,
#                521,
#                563,
#                564,
#                565,
#                567],
#               'cube0_cluster1': [3,
#                9,
#                14,
#                15,
#                22,
#                31,
#                38,
#                60,
#                63,
#                68,
#                71,
#                101,
#                105,
#                112,
#                116,
#                138,
#                146,
#                151,
#                152,
#                157,
#                175,
#                176,
#                178,
#                190,
#                192,
#                203,
#                213,
#                232,
#                247,
#                257,
#                258,
#                259,
#                270,
#                275,
#                288,
#                290,
#                307,
#                314,
#                318,
#                351,
#                376,
#                379,
#                391,
#                424,
#                430,
#                473,
#                504,
#                505,
#                520,
#                528,
#                538,
#                539,
#                557,
#                561,
#                562,
#                568],
#               'cube1_cluster0': [0,
#                18,
#                24,
#                42,
#                72,
#                77,
#                78,
#                108,
#                122,
#                161,
#                181,
#                202,
#                210,
#                219,
#                233,
#                237,
#                250,
#                252,
#                256,
#                260,
#                272,
#                302,
#                323,
#                343,
#                366,
#                369,
#                373,
#                393,
#                417,
#                449,
#                451,
#                563,
#                564,
#                565,
#                567],
#               'cube1_cluster1': [23,
#                82,
#                164,
#                180,
#                212,
#                236,
#                265,
#                339,
#                352,
#                368,
#                461,
#                503,
#                521],
#               'cube2_cluster0': [0,
#                1,
#                2,
#                4,
#                6,
#                10,
#                11,
#                17,
#                18,
#                23,
#                24,
#                25,
#                27,
#                28,
#                29,
#                30,
#                32,
#                33,
#                34,
#                35,
#                42,
#                45,
#                53,
#                56,
#                70,
#                72,
#                75,
#                77,
#                83,
#                85,
#                87,
#                95,
#                118,
#                119,
#                121,
#                127,
#                129,
#                131,
#                132,
#                134,
#                141,
#                156,
#                161,
#                162,
#                164,
#                167,
#                168,
#                181,
#                182,
#                186,
#                197,
#                198,
#                201,
#                202,
#                207,
#                210,
#                218,
#                219,
#                230,
#                233,
#                237,
#                239,
#                244,
#                250,
#                252,
#                253,
#                254,
#                256,
#                260,
#                261,
#                262,
#                264,
#                272,
#                274,
#                277,
#                280,
#                282,
#                300,
#                302,
#                317,
#                321,
#                323,
#                328,
#                335,
#                337,
#                343,
#                365,
#                366,
#                369,
#                370,
#                372,
#                373,
#                389,
#                392,
#                393,
#                400,
#                408,
#                417,
#                432,
#                433,
#                441,
#                444,
#                446,
#                449,
#                451,
#                460,
#                468,
#                487,
#                489,
#                491,
#                492,
#                498,
#                499,
#                503,
#                516,
#                517,
#                521,
#                533,
#                535,
#                563,
#                564,
#                565,
#                566,
#                567],
#               'cube2_cluster1': [5,
#                7,
#                8,
#                9,
#                13,
#                14,
#                15,
#                16,
#                19,
#                20,
#                21,
#                22,
#                26,
#                31,
#                36,
#                37,
#                38,
#                39,
#                40,
#                41,
#                43,
#                44,
#                46,
#                47,
#                48,
#                49,
#                50,
#                51,
#                52,
#                54,
#                55,
#                57,
#                58,
#                59,
#                60,
#                61,
#                62,
#                63,
#                64,
#                65,
#                66,
#                67,
#                68,
#                69,
#                71,
#                73,
#                74,
#                76,
#                79,
#                80,
#                81,
#                84,
#                86,
#                88,
#                89,
#                90,
#                91,
#                92,
#                93,
#                94,
#                96,
#                97,
#                98,
#                99,
#                100,
#                101,
#                102,
#                103,
#                104,
#                105,
#                106,
#                107,
#                109,
#                110,
#                111,
#                112,
#                113,
#                114,
#                115,
#                116,
#                117,
#                120,
#                123,
#                124,
#                125,
#                126,
#                128,
#                130,
#                133,
#                135,
#                136,
#                137,
#                138,
#                139,
#                140,
#                142,
#                143,
#                144,
#                145,
#                146,
#                147,
#                148,
#                149,
#                150,
#                151,
#                153,
#                154,
#                155,
#                157,
#                158,
#                159,
#                160,
#                163,
#                165,
#                166,
#                169,
#                170,
#                171,
#                172,
#                173,
#                174,
#                175,
#                176,
#                177,
#                178,
#                179,
#                183,
#                184,
#                185,
#                187,
#                188,
#                189,
#                191,
#                192,
#                193,
#                194,
#                195,
#                196,
#                199,
#                200,
#                203,
#                204,
#                205,
#                206,
#                208,
#                209,
#                211,
#                214,
#                215,
#                216,
#                217,
#                220,
#                221,
#                222,
#                223,
#                224,
#                225,
#                226,
#                227,
#                228,
#                229,
#                231,
#                232,
#                234,
#                235,
#                238,
#                240,
#                241,
#                242,
#                243,
#                245,
#                246,
#                247,
#                248,
#                249,
#                251,
#                255,
#                257,
#                259,
#                263,
#                266,
#                267,
#                268,
#                269,
#                270,
#                271,
#                273,
#                275,
#                276,
#                278,
#                279,
#                281,
#                283,
#                284,
#                285,
#                286,
#                287,
#                288,
#                289,
#                290,
#                291,
#                292,
#                293,
#                294,
#                295,
#                296,
#                297,
#                298,
#                299,
#                301,
#                303,
#                304,
#                305,
#                306,
#                307,
#                308,
#                309,
#                310,
#                311,
#                312,
#                313,
#                314,
#                315,
#                316,
#                318,
#                319,
#                320,
#                322,
#                324,
#                325,
#                326,
#                327,
#                329,
#                330,
#                331,
#                332,
#                333,
#                334,
#                336,
#                338,
#                340,
#                341,
#                342,
#                344,
#                345,
#                346,
#                347,
#                348,
#                349,
#                350,
#                351,
#                353,
#                354,
#                355,
#                356,
#                357,
#                358,
#                359,
#                360,
#                361,
#                362,
#                363,
#                364,
#                367,
#                371,
#                374,
#                375,
#                376,
#                377,
#                378,
#                379,
#                380,
#                381,
#                382,
#                383,
#                384,
#                385,
#                386,
#                387,
#                388,
#                390,
#                391,
#                394,
#                395,
#                396,
#                397,
#                398,
#                399,
#                401,
#                402,
#                403,
#                404,
#                405,
#                406,
#                407,
#                409,
#                410,
#                411,
#                412,
#                413,
#                414,
#                415,
#                416,
#                418,
#                419,
#                420,
#                421,
#                422,
#                423,
#                424,
#                425,
#                426,
#                427,
#                428,
#                429,
#                430,
#                431,
#                434,
#                435,
#                436,
#                437,
#                438,
#                439,
#                440,
#                442,
#                443,
#                445,
#                447,
#                448,
#                450,
#                452,
#                453,
#                454,
#                455,
#                456,
#                457,
#                458,
#                459,
#                462,
#                463,
#                464,
#                465,
#                466,
#                467,
#                469,
#                470,
#                471,
#                472,
#                473,
#                474,
#                475,
#                476,
#                477,
#                478,
#                479,
#                480,
#                481,
#                482,
#                483,
#                484,
#                485,
#                486,
#                488,
#                490,
#                493,
#                494,
#                495,
#                496,
#                497,
#                500,
#                501,
#                502,
#                504,
#                505,
#                506,
#                507,
#                508,
#                509,
#                510,
#                511,
#                512,
#                513,
#                514,
#                515,
#                518,
#                519,
#                520,
#                522,
#                523,
#                524,
#                525,
#                526,
#                527,
#                528,
#                529,
#                530,
#                531,
#                532,
#                534,
#                536,
#                537,
#                538,
#                539,
#                540,
#                541,
#                542,
#                543,
#                544,
#                545,
#                546,
#                547,
#                548,
#                549,
#                550,
#                551,
#                552,
#                553,
#                554,
#                555,
#                556,
#                557,
#                558,
#                559,
#                560,
#                561,
#                562,
#                568],
#               'cube3_cluster0': [18,
#                23,
#                164,
#                219,
#                236,
#                265,
#                272,
#                339,
#                368,
#                369,
#                503,
#                521],
#               'cube3_cluster1': [0,
#                1,
#                2,
#                4,
#                6,
#                24,
#                30,
#                33,
#                42,
#                45,
#                56,
#                70,
#                72,
#                77,
#                85,
#                87,
#                95,
#                121,
#                127,
#                129,
#                134,
#                161,
#                162,
#                168,
#                181,
#                198,
#                202,
#                210,
#                218,
#                233,
#                237,
#                244,
#                250,
#                252,
#                254,
#                256,
#                260,
#                280,
#                282,
#                300,
#                302,
#                321,
#                323,
#                337,
#                343,
#                365,
#                366,
#                372,
#                373,
#                393,
#                417,
#                432,
#                433,
#                449,
#                451,
#                460,
#                487,
#                498,
#                499,
#                516,
#                517,
#                533,
#                535,
#                563,
#                564,
#                565,
#                567]}),
#  'links': defaultdict(list,
#              {'cube0_cluster0': ['cube1_cluster0',
#                'cube1_cluster1',
#                'cube2_cluster0',
#                'cube3_cluster0',
#                'cube3_cluster1'],
#               'cube0_cluster1': ['cube2_cluster1'],
#               'cube1_cluster0': ['cube2_cluster0',
#                'cube3_cluster0',
#                'cube3_cluster1'],
#               'cube1_cluster1': ['cube2_cluster0', 'cube3_cluster0'],
#               'cube2_cluster0': ['cube3_cluster0', 'cube3_cluster1']}),
#  'simplices': [['cube0_cluster0'],
#   ['cube0_cluster1'],
#   ['cube1_cluster0'],
#   ['cube1_cluster1'],
#   ['cube2_cluster0'],
#   ['cube2_cluster1'],
#   ['cube3_cluster0'],
#   ['cube3_cluster1'],
#   ['cube0_cluster0', 'cube1_cluster0'],
#   ['cube0_cluster0', 'cube1_cluster1'],
#   ['cube0_cluster0', 'cube2_cluster0'],
#   ['cube0_cluster0', 'cube3_cluster0'],
#   ['cube0_cluster0', 'cube3_cluster1'],
#   ['cube0_cluster1', 'cube2_cluster1'],
#   ['cube1_cluster0', 'cube2_cluster0'],
#   ['cube1_cluster0', 'cube3_cluster0'],
#   ['cube1_cluster0', 'cube3_cluster1'],
#   ['cube1_cluster1', 'cube2_cluster0'],
#   ['cube1_cluster1', 'cube3_cluster0'],
#   ['cube2_cluster0', 'cube3_cluster0'],
#   ['cube2_cluster0', 'cube3_cluster1']],
#  'meta_data': {'projection': 'custom',
#   'n_cubes': 2,
#   'perc_overlap': 0.4,
#   'clusterer': 'KMeans(n_clusters=2, random_state=1618033)',
#   'scaler': 'None'},
#  'meta_nodes': defaultdict(list, {})}

# %%
# Original Code from Example
mapper = km.KeplerMapper(verbose=3)
lens2 = mapper.fit_transform(X, projection="l2norm")

lens = np.c_[lens1, lens2]


graph = mapper.map(
    lens,
    X,
    cover=km.Cover(n_cubes=2, perc_overlap=0.4),
    clusterer=sklearn.cluster.KMeans(n_clusters=2, random_state=1618033),#nerve=trial_nerve
)
# Out:
# KeplerMapper(verbose=3)
# ..Composing projection pipeline of length 1:
# 	Projections: l2norm
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (569, 31)
#
# ..Projecting data using: l2norm
#
# ..Scaling with: MinMaxScaler()
#
# Mapping on data shaped (569, 31) using lens shaped (569, 2)
#
# Minimal points in hypercube before clustering: 2
# Creating 4 hypercubes.
#    > Found 2 clusters in hypercube 0.
#    > Found 2 clusters in hypercube 1.
#    > Found 2 clusters in hypercube 2.
#    > Found 2 clusters in hypercube 3.
#
# Created 13 edges and 8 nodes in 0:00:00.041944.

# %%
# Sanity Checks
graph["nodes"] == test.mapper['nodes']
# Out:
# True

# %%
graph["links"] == test.mapper['links']
# Out:
# True

# %%
graph["simplices"] == test.mapper['simplices']
# Out:
# True

# %%
# Convert to Networkx
G = test.mapper_to_networkx()

# %%
nx.draw(G)

# %%
# Generate Conncted Components
a,b = test.connected_components()

# %%
nx.draw(a)

# %%
nx.draw(b)

# %%
# Lookup Item, here by index

    # which clusters is `0` in?
test.item_lookup(0)[0].keys()
# Out:
# dict_keys(['cube0_cluster0', 'cube1_cluster0', 'cube2_cluster0', 'cube3_cluster1'])

# %%
# Subgraph
    # what is the subgraph generated by the clusters that contain `0`. I.e. What does `0` contribute to in Mapper output
nx.draw(test.item_lookup(0)[1])
